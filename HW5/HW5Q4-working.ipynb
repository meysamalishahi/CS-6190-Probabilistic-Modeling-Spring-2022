# %%
import numpy as np
import matplotlib.pyplot as plt
import math

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torch.distributions import Normal as norm

import torchvision.datasets as datasets
import torchvision.transforms as transforms

from termcolor import colored

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Data Process

# %%
trans = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (1.0,))])

# %%
# if not exist, download mnist dataset
mnist_trainset = datasets.MNIST(root='./data', train=True, transform=trans, download=True)
mnist_testset = datasets.MNIST(root='./data', train=False, transform=trans, download=True)

# %%
batch_size = 128
N = len(mnist_trainset)
N
# Out:
# 60000

# %%
N_test = len(mnist_testset)
N_test
# Out:
# 10000

# %%
train_loader = torch.utils.data.DataLoader(
                 dataset=mnist_trainset,
                 batch_size=batch_size,
                 shuffle=True)
test_loader = torch.utils.data.DataLoader(
                dataset=mnist_testset,
                batch_size=N_test,
                shuffle=False)

# %%
FF = nn.Flatten()

# %%
c = 0
for batch_idx, (example_data, example_targets) in enumerate(train_loader):
    c += 1
    print(example_data.shape)
    print(example_targets.shape)
    print("Flatten", FF(example_data).shape)
    if c ==2:   
        break
# Out:
# torch.Size([128, 1, 28, 28])
# torch.Size([128])
# Flatten torch.Size([128, 784])
# torch.Size([128, 1, 28, 28])
# torch.Size([128])
# Flatten torch.Size([128, 784])

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
for i in range(6):
    plt.subplot(2,3,i+1)
    plt.tight_layout()
    plt.imshow(example_data[i][0], cmap='gray', interpolation='none')
    plt.title("Ground Truth: {}".format(example_targets[i]))
    plt.xticks([])
    plt.yticks([])
fig

# %% [markdown]
# # Main functions

# %%
class Gaussian(nn.Module):
    def __init__(self, mu, rho):
        super(Gaussian, self).__init__()
        self.norm   = norm(0,1)
        self.mu_    = mu
        self.rho_   = rho
        self.sigma_ = torch.ones(self.mu_.shape).to(device)
        
        
    def sample(self):
        self.eps    = 1*self.norm.sample(self.mu_.shape).type(self.mu_.type()).to(device)
        self.sigma_ = 1*torch.log(1 + torch.exp(self.rho_)).to(device)
        self.W      = self.mu_ + self.sigma_ * self.eps
        return self.W
            
    def loss(self):
        return (0.5*self.mu_**2 + 0.5*self.sigma_ - torch.log(1e-20 + self.sigma_)).sum()

# %%
class Blinear(nn.Module):
    def __init__(self, n_input, n_output):
        super(Blinear, self).__init__()
        
        
        self.n_input  = n_input
        self.n_output = n_output
        scale = 1.0/np.sqrt(2*self.n_input)
        
        
        
#         self.mu       = nn.Parameter(scale*torch.randn(n_output, n_input))
#         self.rho      = nn.Parameter(scale * torch.ones(n_output, n_input))
        
#         self.W        = Gaussian(self.mu, self.rho)

#         self.b_mu     = nn.Parameter(torch.zeros(n_output))
#         self.b_rho    = nn.Parameter(scale * torch.ones(n_output))
        
#         self.b        = Gaussian(self.b_mu, self.b_rho)
        
        
        
        self.mu    = nn.Parameter(torch.Tensor(n_output, n_input).normal_(0., .05))  # or .01
        self.rho   = nn.Parameter(torch.Tensor(n_output, n_input).uniform_(-3., -3.))
        
        self.W     = Gaussian(self.mu, self.rho)
        
        self.b_mu  = nn.Parameter(torch.Tensor(n_output).normal_(0., .05))
        self.b_rho = nn.Parameter(torch.Tensor(n_output).uniform_(-3., -3.))
        
        self.b     = Gaussian(self.b_mu, self.b_rho)
        
        
        
        
        
    def forward(self, x):
        
        W = self.W.sample()
        b = self.b.sample()
        
        return F.linear(x, W, b)

# %%
class BNet(nn.Module):
    
    def __init__(self, layers, act):
        super(BNet, self).__init__()
        
        self.act = act
        self.fc  = nn.ModuleList()
        self.flatten = nn.Flatten()
        for i in range(len(layers) - 1):
            self.fc.append(Blinear(layers[i], layers[i+1]))  
            
            
    def forward(self,x):
        x = self.flatten(x)
        for i in range(len(self.fc) - 1):
            x = self.fc[i].forward(x) #forward based on Blinear 
            x = self.act(x)
            
        x = F.log_softmax(self.fc[-1](x), dim=1)
        
        return x

# %%
class BNN():
    def __init__(self, train_loader, layers, act, n_epochs = 10000):
        
        self.train_loader = train_loader
        self.n_layers = len(layers)
        
        self.nepochs = n_epochs
        self.BNet    = BNet(layers, act)
        
    def get_neg_elbo(self):
        neg_elbo = 0
        for i in range(self.n_layers-1):
            neg_elbo += self.BNet.fc[i].W.loss()
            neg_elbo += self.BNet.fc[i].b.loss()
            
        p_pred = self.BNet(self.x)
        
        return neg_elbo + N/batch_size * F.nll_loss(p_pred, self.y, reduction='mean') 
    
    def train(self, lr, decay, step_size = 1000):
    
        optimizer = torch.optim.Adam(self.BNet.parameters(), lr = lr)
        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=decay)
        
        for n in range(self.nepochs):
            for batch_idx, (example_data, example_targets) in enumerate(train_loader):
                
                self.x = example_data
                self.y = example_targets
             
                loss = self.get_neg_elbo()
                if batch_idx %10 == 0:
                    print(n, batch_idx)
                    with torch.no_grad():
                        print("Loss = ", loss.item())
                        acc = 0
                        pl = 0
                        for i in range(100):
                            p_pred = self.BNet(self.x).numpy()

#                             pl += sum([np.log(p_pred[self.y == a]) for a in range(10)])/p_pred.shape[0]

                        
                            y_hat = np.argmax(p_pred, axis = 1)
                        
                            acc += (self.y.numpy() == y_hat).astype(int).mean()
                    
                        print(colored('learning rate:{}'.format(optimizer.param_groups[0]['lr']), 'blue'))
                        print(colored('Train accuracy for iteration {} is {}'.format(n, acc/100), 'red'))
#                         print('Predictive log-likelihood for trainat iteration {} is {}'.format(n, pl/100))
                    
                    
                optimizer.zero_grad()
                loss.backward(retain_graph=True)
                optimizer.step()
                scheduler.step()

# %%
# l = [10,10]
# lr = 1e-3

# %%
for lr in [1e-3, 1e-4, 1e-5]:
    print('---------------------------------------------------------------------')
    print('---------------------------------------------------------------------')
    #print(colored("\n\n Start training for lr = {} and hidden_layer size = {}\n\n".format(lr, l), 'green'))
    print('---------------------------------------------------------------------')
    print('---------------------------------------------------------------------')
    model = BNN(train_loader, [784, 800, 800, 10], act = nn.ReLU(), n_epochs = 2)
    model.train(lr = 1e-3, decay = 1)
    #models.append(model)
    print('---------------------------------------------------------------------')
    print('---------------------------------------------------------------------')
    
    for _, (example_data, example_targets) in enumerate(test_loader):
        A = example_data
        b = example_targets
    z = model.BNet(A).detach()
    T_pred = torch.argmax(z, dim = 1)
    print((T_pred == b).sum()/len(T_pred))
# Out:
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# 0 0
# Loss =  641369.0625
# learning rate:0.001
# Train accuracy for iteration 0 is 0.090625
# 0 10
# Loss =  3888415.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.20296875
# 0 20
# Loss =  3877030.0
# learning rate:0.001
# Train accuracy for iteration 0 is 0.309296875
# 0 30
# Loss =  3865609.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.243203125
# 0 40
# Loss =  3854221.0
# learning rate:0.001
# Train accuracy for iteration 0 is 0.372890625
# 0 50
# Loss =  3842487.0
# learning rate:0.001
# Train accuracy for iteration 0 is 0.39515625
# 0 60
# Loss =  3831072.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.499140625
# 0 70
# Loss =  3819543.0
# learning rate:0.001
# Train accuracy for iteration 0 is 0.53421875
# 0 80
# Loss =  3808045.25
# learning rate:0.001
# Train accuracy for iteration 0 is 0.601640625
# 0 90
# Loss =  3796978.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.614453125
# 0 100
# Loss =  3785350.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.649296875
# 0 110
# Loss =  3773961.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.674140625
# 0 120
# Loss =  3762600.0
# learning rate:0.001
# Train accuracy for iteration 0 is 0.71578125
# 0 130
# Loss =  3751323.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.711171875
# 0 140
# Loss =  3740007.25
# learning rate:0.001
# Train accuracy for iteration 0 is 0.69375
# 0 150
# Loss =  3728549.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.68234375
# 0 160
# Loss =  3717332.25
# learning rate:0.001
# Train accuracy for iteration 0 is 0.720234375
# 0 170
# Loss =  3705981.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.7634375
# 0 180
# Loss =  3694598.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.757578125
# 0 190
# Loss =  3683200.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.768515625
# 0 200
# Loss =  3672103.0
# learning rate:0.001
# Train accuracy for iteration 0 is 0.684453125
# 0 210
# Loss =  3660627.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.746328125
# 0 220
# Loss =  3649401.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.721640625
# 0 230
# Loss =  3638183.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.808046875
# 0 240
# Loss =  3626783.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.791953125
# 0 250
# Loss =  3615533.0
# learning rate:0.001
# Train accuracy for iteration 0 is 0.7859375
# 0 260
# Loss =  3604389.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.75625
# 0 270
# Loss =  3593137.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.73078125
# 0 280
# Loss =  3581765.0
# learning rate:0.001
# Train accuracy for iteration 0 is 0.79765625
# 0 290
# Loss =  3570581.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.806015625
# 0 300
# Loss =  3559437.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.794453125
# 0 310
# Loss =  3548187.25
# learning rate:0.001
# Train accuracy for iteration 0 is 0.796015625
# 0 320
# Loss =  3537016.25
# learning rate:0.001
# Train accuracy for iteration 0 is 0.7465625
# 0 330
# Loss =  3525695.0
# learning rate:0.001
# Train accuracy for iteration 0 is 0.815625
# 0 340
# Loss =  3514626.0
# learning rate:0.001
# Train accuracy for iteration 0 is 0.78078125
# 0 350
# Loss =  3503648.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.733203125
# 0 360
# Loss =  3492231.25
# learning rate:0.001
# Train accuracy for iteration 0 is 0.758046875
# 0 370
# Loss =  3481111.25
# learning rate:0.001
# Train accuracy for iteration 0 is 0.786015625
# 0 380
# Loss =  3469997.25
# learning rate:0.001
# Train accuracy for iteration 0 is 0.7803125
# 0 390
# Loss =  3458797.0
# learning rate:0.001
# Train accuracy for iteration 0 is 0.79828125
# 0 400
# Loss =  3447630.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.818671875
# 0 410
# Loss =  3436613.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.826953125
# 0 420
# Loss =  3425489.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.846953125
# 0 430
# Loss =  3414522.25
# learning rate:0.001
# Train accuracy for iteration 0 is 0.74234375
# 0 440
# Loss =  3403395.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.775234375
# 0 450
# Loss =  3392382.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.775546875
# 0 460
# Loss =  3381148.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.8028125
# 1 0
# Loss =  3371431.75
# learning rate:0.001
# Train accuracy for iteration 1 is 0.793515625
# 1 10
# Loss =  3360405.0
# learning rate:0.001
# Train accuracy for iteration 1 is 0.8025
# 1 20
# Loss =  3349309.75
# learning rate:0.001
# Train accuracy for iteration 1 is 0.79671875
# 1 30
# Loss =  3338290.75
# learning rate:0.001
# Train accuracy for iteration 1 is 0.750390625
# 1 40
# Loss =  3327220.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.796875
# 1 50
# Loss =  3316221.0
# learning rate:0.001
# Train accuracy for iteration 1 is 0.814765625
# 1 60
# Loss =  3305366.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.83234375
# 1 70
# Loss =  3294467.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.778671875
# 1 80
# Loss =  3283241.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.849609375
# 1 90
# Loss =  3272395.5
# learning rate:0.001
# Train accuracy for iteration 1 is 0.806484375
# 1 100
# Loss =  3261769.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.799296875
# 1 110
# Loss =  3250717.0
# learning rate:0.001
# Train accuracy for iteration 1 is 0.75625
# 1 120
# Loss =  3239745.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.80296875
# 1 130
# Loss =  3228901.5
# learning rate:0.001
# Train accuracy for iteration 1 is 0.74015625
# 1 140
# Loss =  3217799.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.823046875
# 1 150
# Loss =  3206977.5
# learning rate:0.001
# Train accuracy for iteration 1 is 0.81796875
# 1 160
# Loss =  3196170.5
# learning rate:0.001
# Train accuracy for iteration 1 is 0.772109375
# 1 170
# Loss =  3185256.0
# learning rate:0.001
# Train accuracy for iteration 1 is 0.827890625
# 1 180
# Loss =  3174387.75
# learning rate:0.001
# Train accuracy for iteration 1 is 0.8190625
# 1 190
# Loss =  3163849.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.768515625
# 1 200
# Loss =  3152851.75
# learning rate:0.001
# Train accuracy for iteration 1 is 0.78015625
# 1 210
# Loss =  3142194.0
# learning rate:0.001
# Train accuracy for iteration 1 is 0.8046875
# 1 220
# Loss =  3131162.0
# learning rate:0.001
# Train accuracy for iteration 1 is 0.79328125
# 1 230
# Loss =  3120521.0
# learning rate:0.001
# Train accuracy for iteration 1 is 0.738125
# 1 240
# Loss =  3109664.75
# learning rate:0.001
# Train accuracy for iteration 1 is 0.7728125
# 1 250
# Loss =  3099188.0
# learning rate:0.001
# Train accuracy for iteration 1 is 0.82078125
# 1 260
# Loss =  3088377.75
# learning rate:0.001
# Train accuracy for iteration 1 is 0.708359375
# 1 270
# Loss =  3077532.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.7746875
# 1 280
# Loss =  3066776.75
# learning rate:0.001
# Train accuracy for iteration 1 is 0.796015625
# 1 290
# Loss =  3056147.75
# learning rate:0.001
# Train accuracy for iteration 1 is 0.75640625
# 1 300
# Loss =  3045732.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.74109375
# 1 310
# Loss =  3034900.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.7584375
# 1 320
# Loss =  3024212.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.8075
# 1 330
# Loss =  3013483.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.784765625
# 1 340
# Loss =  3003108.0
# learning rate:0.001
# Train accuracy for iteration 1 is 0.706796875
# 1 350
# Loss =  2992542.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.793828125
# 1 360
# Loss =  2981860.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.771953125
# 1 370
# Loss =  2971263.75
# learning rate:0.001
# Train accuracy for iteration 1 is 0.765234375
# 1 380
# Loss =  2960729.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.745625
# 1 390
# Loss =  2950273.5
# learning rate:0.001
# Train accuracy for iteration 1 is 0.7453125
# 1 400
# Loss =  2939625.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.71046875
# 1 410
# Loss =  2929250.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.703515625
# 1 420
# Loss =  2918620.5
# learning rate:0.001
# Train accuracy for iteration 1 is 0.765625
# 1 430
# Loss =  2908332.5
# learning rate:0.001
# Train accuracy for iteration 1 is 0.72984375
# 1 440
# Loss =  2897731.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.736171875
# 1 450
# Loss =  2887266.5
# learning rate:0.001
# Train accuracy for iteration 1 is 0.740625
# 1 460
# Loss =  2876894.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.79671875
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# tensor(0.8366)
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# 0 0
# Loss =  641479.9375
# learning rate:0.001
# Train accuracy for iteration 0 is 0.100546875
# 0 10
# Loss =  3888992.25
# learning rate:0.001
# Train accuracy for iteration 0 is 0.168046875
# 0 20
# Loss =  3877221.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.195
# 0 30
# Loss =  3865702.0
# learning rate:0.001
# Train accuracy for iteration 0 is 0.235234375
# 0 40
# Loss =  3854350.25
# learning rate:0.001
# Train accuracy for iteration 0 is 0.363359375
# 0 50
# Loss =  3842572.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.4140625
# 0 60
# Loss =  3831081.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.439609375
# 0 70
# Loss =  3819760.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.516015625
# 0 80
# Loss =  3808223.25
# learning rate:0.001
# Train accuracy for iteration 0 is 0.58390625
# 0 90
# Loss =  3796787.0
# learning rate:0.001
# Train accuracy for iteration 0 is 0.56578125
# 0 100
# Loss =  3785287.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.599453125
# 0 110
# Loss =  3774083.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.66796875
# 0 120
# Loss =  3762616.25
# learning rate:0.001
# Train accuracy for iteration 0 is 0.658359375
# 0 130
# Loss =  3751302.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.634921875
# 0 140
# Loss =  3739785.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.714296875
# 0 150
# Loss =  3728382.25
# learning rate:0.001
# Train accuracy for iteration 0 is 0.706953125
# 0 160
# Loss =  3717039.25
# learning rate:0.001
# Train accuracy for iteration 0 is 0.742109375
# 0 170
# Loss =  3705764.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.733671875
# 0 180
# Loss =  3694380.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.7446875
# 0 190
# Loss =  3683032.0
# learning rate:0.001
# Train accuracy for iteration 0 is 0.75875
# 0 200
# Loss =  3671698.25
# learning rate:0.001
# Train accuracy for iteration 0 is 0.759765625
# 0 210
# Loss =  3660352.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.774453125
# 0 220
# Loss =  3649095.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.803046875
# 0 230
# Loss =  3637795.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.77359375
# 0 240
# Loss =  3626548.25
# learning rate:0.001
# Train accuracy for iteration 0 is 0.809453125
# 0 250
# Loss =  3615443.0
# learning rate:0.001
# Train accuracy for iteration 0 is 0.7484375
# 0 260
# Loss =  3604029.25
# learning rate:0.001
# Train accuracy for iteration 0 is 0.777265625
# 0 270
# Loss =  3592694.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.820625
# 0 280
# Loss =  3581515.25
# learning rate:0.001
# Train accuracy for iteration 0 is 0.796328125
# 0 290
# Loss =  3570235.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.816640625
# 0 300
# Loss =  3558968.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.81203125
# 0 310
# Loss =  3547794.0
# learning rate:0.001
# Train accuracy for iteration 0 is 0.758125
# 0 320
# Loss =  3536508.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.84515625
# 0 330
# Loss =  3525363.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.78046875
# 0 340
# Loss =  3514132.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.79953125
# 0 350
# Loss =  3503036.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.796484375
# 0 360
# Loss =  3491764.25
# learning rate:0.001
# Train accuracy for iteration 0 is 0.8
# 0 370
# Loss =  3480612.0
# learning rate:0.001
# Train accuracy for iteration 0 is 0.795234375
# 0 380
# Loss =  3469600.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.750859375
# 0 390
# Loss =  3458405.0
# learning rate:0.001
# Train accuracy for iteration 0 is 0.79234375
# 0 400
# Loss =  3447205.75
# learning rate:0.001
# Train accuracy for iteration 0 is 0.81171875
# 0 410
# Loss =  3436119.0
# learning rate:0.001
# Train accuracy for iteration 0 is 0.781640625
# 0 420
# Loss =  3425123.25
# learning rate:0.001
# Train accuracy for iteration 0 is 0.778125
# 0 430
# Loss =  3413853.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.8071875
# 0 440
# Loss =  3402931.5
# learning rate:0.001
# Train accuracy for iteration 0 is 0.737734375
# 0 450
# Loss =  3391774.0
# learning rate:0.001
# Train accuracy for iteration 0 is 0.751484375
# 0 460
# Loss =  3380693.25
# learning rate:0.001
# Train accuracy for iteration 0 is 0.73015625
# 1 0
# Loss =  3370869.5
# learning rate:0.001
# Train accuracy for iteration 1 is 0.75625
# 1 10
# Loss =  3359998.5
# learning rate:0.001
# Train accuracy for iteration 1 is 0.801640625
# 1 20
# Loss =  3348717.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.837734375
# 1 30
# Loss =  3337735.5
# learning rate:0.001
# Train accuracy for iteration 1 is 0.804921875
# 1 40
# Loss =  3326697.75
# learning rate:0.001
# Train accuracy for iteration 1 is 0.777421875
# 1 50
# Loss =  3315770.5
# learning rate:0.001
# Train accuracy for iteration 1 is 0.77078125
# 1 60
# Loss =  3304872.0
# learning rate:0.001
# Train accuracy for iteration 1 is 0.772734375
# 1 70
# Loss =  3293709.75
# learning rate:0.001
# Train accuracy for iteration 1 is 0.79875
# 1 80
# Loss =  3282929.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.7303125
# 1 90
# Loss =  3271693.0
# learning rate:0.001
# Train accuracy for iteration 1 is 0.814921875
# 1 100
# Loss =  3261022.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.7765625
# 1 110
# Loss =  3249951.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.796640625
# 1 120
# Loss =  3239122.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.83234375
# 1 130
# Loss =  3228258.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.735078125
# 1 140
# Loss =  3217261.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.764375
# 1 150
# Loss =  3206340.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.8075
# 1 160
# Loss =  3195693.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.794140625
# 1 170
# Loss =  3184533.75
# learning rate:0.001
# Train accuracy for iteration 1 is 0.822109375
# 1 180
# Loss =  3173856.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.827890625
# 1 190
# Loss =  3162984.0
# learning rate:0.001
# Train accuracy for iteration 1 is 0.774296875
# 1 200
# Loss =  3152428.0
# learning rate:0.001
# Train accuracy for iteration 1 is 0.75125
# 1 210
# Loss =  3141506.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.7759375
# 1 220
# Loss =  3130587.75
# learning rate:0.001
# Train accuracy for iteration 1 is 0.807421875
# 1 230
# Loss =  3120112.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.767265625
# 1 240
# Loss =  3109180.75
# learning rate:0.001
# Train accuracy for iteration 1 is 0.77703125
# 1 250
# Loss =  3098493.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.789609375
# 1 260
# Loss =  3087653.0
# learning rate:0.001
# Train accuracy for iteration 1 is 0.77703125
# 1 270
# Loss =  3076946.25
# learning rate:0.001
# Train accuracy for iteration 1 is 0.76703125
# 1 280
# Loss =  3066269.0
# learning rate:0.001
# Train accuracy for iteration 1 is 0.768984375
# 1 290
# Loss =  3055566.5
# learning rate:0.001
# Train accuracy for iteration 1 is 0.78
# 1 300
# Loss =  3044759.75
# learning rate:0.001
# Train accuracy for iteration 1 is 0.835703125
# 1 310
# Loss =  3034302.5
# learning rate:0.001
# Train accuracy for iteration 1 is 0.80921875
# 1 320
# Loss =  3023660.75
# learning rate:0.001
# Train accuracy for iteration 1 is 0.752578125
# 1 330
# Loss =  3013005.75
# learning rate:0.001
# Train accuracy for iteration 1 is 0.78484375
# 1 340
# Loss =  3002401.25

# %%
torch.clamp(torch.tensor([3,2,-1,6]), max = 3)
