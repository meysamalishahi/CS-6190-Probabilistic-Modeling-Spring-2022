# %%
import numpy as np
import matplotlib.pyplot as plt
import math

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torch.distributions import Normal as norm

from termcolor import colored

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Data Process

# %%
data = np.genfromtxt("data/bank-note/train.csv", dtype = float, delimiter = ',')
data.shape
# Out:
# (872, 5)

# %%
data = np.hstack((np.ones((data.shape[0],1)), data))
data.shape
# Out:
# (872, 6)

# %%
train_data = data[:,:-1]
train_label = data[:,-1].astype(int)
train_data.shape, train_label.shape
# Out:
# ((872, 5), (872,))

# %%
train = torch.tensor(train_data).type(torch.FloatTensor)
label = torch.tensor(train_label).type(torch.LongTensor)

# %%
test_ = np.genfromtxt("data/bank-note/test.csv", dtype = float, delimiter = ',')
test_.shape
# Out:
# (500, 5)

# %%
test_data = np.hstack((np.ones((test_.shape[0],1)), test_))
test_data.shape
# Out:
# (500, 6)

# %%
test__ = test_data[:,:-1]
t__ = test_data[:,-1].astype(int)
test__.shape, t__.shape
# Out:
# ((500, 5), (500,))

# %%
test = torch.tensor(test__).type(torch.FloatTensor)
t = torch.tensor(t__).type(torch.LongTensor)

# %% [markdown]
# ## Main functions

# %%
class Gaussian(nn.Module):
    def __init__(self, mu, rho):
        super(Gaussian, self).__init__()
        self.norm   = norm(0,1)
        self.mu_    = mu
        self.rho_   = rho
        self.sigma_ = torch.ones(self.mu_.shape)
        
        
    def sample(self):
        self.eps    = self.norm.sample(self.mu_.shape).type(self.mu_.type()).to(device)
        self.sigma_ = torch.log(1 + torch.exp(self.rho_))
        self.W      = self.mu_ + self.sigma_ * self.eps
        return self.W
            
    def loss(self):
        return (0.5*self.mu_**2 + 0.5*self.sigma_ - torch.log(1e-20 + self.sigma_)).sum()

# %%
class Blinear(nn.Module):
    def __init__(self, n_input, n_output):
        super(Blinear, self).__init__()
        
        

        
        self.n_input  = n_input
        self.n_output = n_output
        scale = 1.0/np.sqrt(2*self.n_input)
        
        
        #self.mu       = nn.Parameter(norm(0,1).sample((n_output, n_input)))
        
        self.mu       = nn.Parameter(scale*torch.randn(n_output, n_input))
        
        
        
        #self.mu       = nn.Parameter(torch.zeros(n_output, n_input))
        self.rho      = nn.Parameter(scale * torch.ones(n_output, n_input))
        
        self.W        = Gaussian(self.mu, self.rho)

        self.b_mu     = nn.Parameter(torch.zeros(n_output))
        self.b_rho    = nn.Parameter(scale * torch.ones(n_output))
        self.b        = Gaussian(self.b_mu, self.b_rho)
        
    def forward(self, x):
        
        W = self.W.sample()
        b = self.b.sample()
        
        return F.linear(x, W, b)

# %%
class BNet(nn.Module):
    
    def __init__(self, layers, act):
        super(BNet, self).__init__()
        
        self.act = act
        self.fc  = nn.ModuleList()
        for i in range(len(layers) - 1):
            self.fc.append(Blinear(layers[i], layers[i+1]))  
            
            
    def forward(self,x):
        for i in range(len(self.fc) - 1):
            x = self.fc[i].forward(x) #forward based on Blinear 
            x = self.act(x)
            
        x = F.log_softmax(self.fc[-1](x), dim=1)
        #x = F.softmax(self.fc[-1].forward(x), dim=1)
        
        return x

# %%
class BNN():
    def __init__(self, x, y, layers, act, n_epochs = 10000):
        
        self.x = x
        self.y = y
        self.n_layers = len(layers)
        
        self.nepochs = n_epochs
        self.BNet    = BNet(layers, act)
        
    def get_neg_elbo(self):
        neg_elbo = 0
        for i in range(self.n_layers-1):
            neg_elbo += self.BNet.fc[i].W.loss()
            neg_elbo += self.BNet.fc[i].b.loss()
            
        #print('neg_elbo', neg_elbo)
            
        p_pred = self.BNet(self.x)
        
        return neg_elbo - p_pred[self.y==1, 1].sum() - p_pred[self.y==0, 0].sum()
        
#         return neg_elbo + F.nll_loss(p_pred, self.y, reduction='sum') #mean or sum?!!!
    
    def train(self, lr, decay, step_size = 1000):
    
        optimizer = torch.optim.Adam(self.BNet.parameters(), lr = lr)
        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=500, gamma=decay)
        
        for n in range(self.nepochs):
            loss = self.get_neg_elbo()
            if n %1000 == 0:
                with torch.no_grad():
                    print(loss.item())
                    acc = 0
                    pl = 0
                    for i in range(1000):
                        p_pred = self.BNet(self.x).numpy()
                        

#                         pl += ((np.log(1e-10+p_pred[self.y==0, 0])).sum() + 
#                                (np.log(1e-10+p_pred[self.y==1, 1])).sum())/p_pred.shape[0]

                        pl += (p_pred[self.y==0, 0].sum() + 
                               p_pred[self.y==1, 1].sum())/p_pred.shape[0]

                        
                        y_hat = np.argmax(p_pred, axis = 1)
                        
                        acc += (self.y.numpy() == y_hat).astype(int).mean()
                    
                    print(colored('learning rate:{}'.format(optimizer.param_groups[0]['lr']), 'blue'))
                        
                    print(colored('Train accuracy for iteration {} is {}'.format(n, acc/1000), 'red'))
                    #print('Train Accuracy for iteration {} is {}'.format(n, acc/1000))
                    print('Predictive log-likelihood for trainat iteration {} is {}'.format(n, pl/1000))
                    
                    
                    acc = 0
                    pl = 0
                    for i in range(1000):

                        t_pred = self.BNet(test).numpy()

                        pl += (t_pred[t==0, 0].sum() + 
                               t_pred[t==1, 1].sum())/t_pred.shape[0]
                        
#                         pl += ((np.log(1e-10+t_pred[t==0, 0])).sum() + 
#                                (np.log(1e-10+t_pred[t==1, 1])).sum())/t_pred.shape[0]
                        
                        t_hat = np.argmax(t_pred, axis = 1)
                        acc += (t.numpy() == t_hat).astype(int).mean()
                    
                    print('Test accuracy is {}'.format(acc/1000))
                    print('Predictive log-likelihood for test at iteration {} is {}'.format(n, pl/1000))
                    
                    
                    
                    
                    
#                     for p in self.BNet.parameters():
#                         print('parametr', p)
                    
                    
            optimizer.zero_grad()
            loss.backward(retain_graph=True)
            optimizer.step()
            scheduler.step()
            
            
        
#         acc = 0
#         for i in range(1000):
#             with torch.no_grad():
#                 y_pred = self.BNet(train).numpy()
#                 y_hat = np.argmax(y_pred, axis = 1)
#                 acc += (label.numpy() == y_hat).astype(int).mean()
                    
#         print(colored('Train accuracy for iteration {} is {}'.format(n, acc/1000), 'red'))            

        
#         acc = 0
#         for i in range(1000):
#             with torch.no_grad():
#                 t_pred = self.BNet(test).numpy()
#                 t_hat  = np.argmax(t_pred, axis = 1)
#                 acc   += (t.numpy() == t_hat).astype(int).mean()
                    
#         print('Test accuracy is {}'.format(acc/1000))

# %%
models = []
for lr in [9e-3]:#[1e-3, 0.5e-3, 1e-4, 1e-5]:
    for l in [10,20,50]:
        
        print('---------------------------------------------------------------------')
        print('---------------------------------------------------------------------')
        print(colored("\n\n Start training for lr = {} and hidden_layer size = {}\n\n".format(lr, l), 'green'))
        print('---------------------------------------------------------------------')
        print('---------------------------------------------------------------------')
        model = BNN(train, label, [5, 10, 10, 2], act = nn.ReLU(), n_epochs = 10000)
        model.train(lr = 9e-3, decay = .95)
        models.append(model)
        print('---------------------------------------------------------------------')
        print('---------------------------------------------------------------------')
# Out:
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
#
#
#  Start training for lr = 0.009 and hidden_layer size = 10
#
#
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# 2115.61865234375
# learning rate:0.009
# Train accuracy for iteration 0 is 0.5091215596330281
# Predictive log-likelihood for trainat iteration 0 is -10.279756968821959
# Test accuracy is 0.5038199999999999
# Predictive log-likelihood for test at iteration 0 is -11.730947324066163
# 1957.73291015625
# learning rate:0.008122499999999998
# Train accuracy for iteration 1000 is 0.5162970183486263
# Predictive log-likelihood for trainat iteration 1000 is -0.8400718373639878
# Test accuracy is 0.5202479999999993
# Predictive log-likelihood for test at iteration 1000 is -0.8335117177734375
# 843.295166015625
# learning rate:0.0073305562499999975
# Train accuracy for iteration 2000 is 0.5313600917431235
# Predictive log-likelihood for trainat iteration 2000 is -0.724283545817803
# Test accuracy is 0.5332359999999977
# Predictive log-likelihood for test at iteration 2000 is -0.7333485831604001
# 854.105712890625
# learning rate:0.006615827015624996
# Train accuracy for iteration 3000 is 0.5420745412844091
# Predictive log-likelihood for trainat iteration 3000 is -0.7110647675050505
# Test accuracy is 0.5455059999999965
# Predictive log-likelihood for test at iteration 3000 is -0.7072972167358393
# 756.097900390625
# learning rate:0.005970783881601559
# Train accuracy for iteration 4000 is 0.5440527522935842
# Predictive log-likelihood for trainat iteration 4000 is -0.7019498758228553
# Test accuracy is 0.5485219999999963
# Predictive log-likelihood for test at iteration 4000 is -0.7008150259704592
# 800.0389404296875
# learning rate:0.005388632453145407
# Train accuracy for iteration 5000 is 0.5399564220183544
# Predictive log-likelihood for trainat iteration 5000 is -0.6978897617585067
# Test accuracy is 0.5460099999999963
# Predictive log-likelihood for test at iteration 5000 is -0.6910877465515144
# 605.185546875
# learning rate:0.004863240788963729
# Train accuracy for iteration 6000 is 0.7313910550458707
# Predictive log-likelihood for trainat iteration 6000 is -0.5685605380032038
# Test accuracy is 0.7327579999999997
# Predictive log-likelihood for test at iteration 6000 is -0.578166906280518
# 332.6693420410156
# learning rate:0.004389074812039765
# Train accuracy for iteration 7000 is 0.9547075688073389
# Predictive log-likelihood for trainat iteration 7000 is -0.16266243832264463
# Test accuracy is 0.9540500000000006
# Predictive log-likelihood for test at iteration 7000 is -0.16243192613220211
# 304.2472229003906
# learning rate:0.003961140017865888
# Train accuracy for iteration 8000 is 0.9780688073394529
# Predictive log-likelihood for trainat iteration 8000 is -0.08555300173409483
# Test accuracy is 0.9762480000000022
# Predictive log-likelihood for test at iteration 8000 is -0.0954443730869292
# 350.1077575683594
# learning rate:0.003574928866123963
# Train accuracy for iteration 9000 is 0.9825068807339479
# Predictive log-likelihood for trainat iteration 9000 is -0.07372280904678033
# Test accuracy is 0.980990000000002
# Predictive log-likelihood for test at iteration 9000 is -0.07563725656509408
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
#
#
#  Start training for lr = 0.009 and hidden_layer size = 20
#
#
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# 7336.009765625
# learning rate:0.009
# Train accuracy for iteration 0 is 0.5130229357798165
# Predictive log-likelihood for trainat iteration 0 is -11.564833570182888
# Test accuracy is 0.510988
# Predictive log-likelihood for test at iteration 0 is -12.66514027021789
# 1847.41943359375
# learning rate:0.008122499999999998
# Train accuracy for iteration 1000 is 0.5264805045871582
# Predictive log-likelihood for trainat iteration 1000 is -0.8256180671901889
# Test accuracy is 0.5244579999999988
# Predictive log-likelihood for test at iteration 1000 is -0.8305095526123047
# 778.2242431640625
# learning rate:0.0073305562499999975
# Train accuracy for iteration 2000 is 0.5315240825688111
# Predictive log-likelihood for trainat iteration 2000 is -0.7132512243428356
# Test accuracy is 0.5407319999999978
# Predictive log-likelihood for test at iteration 2000 is -0.7255182116699225
# 705.4104614257812
# learning rate:0.006615827015624996
# Train accuracy for iteration 3000 is 0.5367522935779863
# Predictive log-likelihood for trainat iteration 3000 is -0.7009202963802796
# Test accuracy is 0.5413779999999976
# Predictive log-likelihood for test at iteration 3000 is -0.6973129122924804
# 563.2340087890625
# learning rate:0.005970783881601559
# Train accuracy for iteration 4000 is 0.8538279816513753
# Predictive log-likelihood for trainat iteration 4000 is -0.38272555883215137
# Test accuracy is 0.8558960000000005
# Predictive log-likelihood for test at iteration 4000 is -0.3880414723510745
# 237.45556640625
# learning rate:0.005388632453145407
# Train accuracy for iteration 5000 is 0.9845986238532145
# Predictive log-likelihood for trainat iteration 5000 is -0.06216052893761112
# Test accuracy is 0.983906000000003
# Predictive log-likelihood for test at iteration 5000 is -0.06828123298168193
# 325.9890441894531
# learning rate:0.004863240788963729
# Train accuracy for iteration 6000 is 0.9901811926605538
# Predictive log-likelihood for trainat iteration 6000 is -0.04512736110293542
# Test accuracy is 0.9898540000000031
# Predictive log-likelihood for test at iteration 6000 is -0.041074416573762915
# 225.6843719482422
# learning rate:0.004389074812039765
# Train accuracy for iteration 7000 is 0.9955240825688108
# Predictive log-likelihood for trainat iteration 7000 is -0.02237560901141497
# Test accuracy is 0.9937900000000036
# Predictive log-likelihood for test at iteration 7000 is -0.025251185360193266
# 212.30691528320312
# learning rate:0.003961140017865888
# Train accuracy for iteration 8000 is 0.9956983944954156
# Predictive log-likelihood for trainat iteration 8000 is -0.01857248342357608
# Test accuracy is 0.9957600000000031
# Predictive log-likelihood for test at iteration 8000 is -0.023901969707295283
# 214.58624267578125
# learning rate:0.003574928866123963
# Train accuracy for iteration 9000 is 0.9961250000000028
# Predictive log-likelihood for trainat iteration 9000 is -0.018965767131024686
# Test accuracy is 0.9955620000000042
# Predictive log-likelihood for test at iteration 9000 is -0.021949857149664298
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
#
#
#  Start training for lr = 0.009 and hidden_layer size = 50
#
#
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# 8507.279296875
# learning rate:0.009
# Train accuracy for iteration 0 is 0.4922603211009172
# Predictive log-likelihood for trainat iteration 0 is -11.525140165276484
# Test accuracy is 0.49802400000000047
# Predictive log-likelihood for test at iteration 0 is -12.03235839898683
# 786.5757446289062
# learning rate:0.008122499999999998
# Train accuracy for iteration 1000 is 0.5155928899082585
# Predictive log-likelihood for trainat iteration 1000 is -0.8158847396570605
# Test accuracy is 0.5174899999999992
# Predictive log-likelihood for test at iteration 1000 is -0.8212800928955067
# 803.2880859375
# learning rate:0.0073305562499999975
# Train accuracy for iteration 2000 is 0.5431100917431236
# Predictive log-likelihood for trainat iteration 2000 is -0.7255249087132435
# Test accuracy is 0.5451879999999975
# Predictive log-likelihood for test at iteration 2000 is -0.7225917795410151
# 805.844482421875
# learning rate:0.006615827015624996
# Train accuracy for iteration 3000 is 0.5477844036697302
# Predictive log-likelihood for trainat iteration 3000 is -0.7006804800471038
# Test accuracy is 0.551483999999997
# Predictive log-likelihood for test at iteration 3000 is -0.7123921994018557
# 800.5078125
# learning rate:0.005970783881601559
# Train accuracy for iteration 4000 is 0.5529288990825749
# Predictive log-likelihood for trainat iteration 4000 is -0.7028155730711214
# Test accuracy is 0.5572299999999965
# Predictive log-likelihood for test at iteration 4000 is -0.7024112403564453
# 800.8673706054688
# learning rate:0.005388632453145407
# Train accuracy for iteration 5000 is 0.5530722477064278
# Predictive log-likelihood for trainat iteration 5000 is -0.6996949592380354
# Test accuracy is 0.5577199999999968
# Predictive log-likelihood for test at iteration 5000 is -0.7073247150268555
# 797.8275146484375
# learning rate:0.004863240788963729
# Train accuracy for iteration 6000 is 0.5644438073394544
# Predictive log-likelihood for trainat iteration 6000 is -0.6991067439787981
# Test accuracy is 0.5697559999999972
# Predictive log-likelihood for test at iteration 6000 is -0.6962572132873526
# 793.1494140625
# learning rate:0.004389074812039765
# Train accuracy for iteration 7000 is 0.580983944954131
# Predictive log-likelihood for trainat iteration 7000 is -0.6990578542936826
# Test accuracy is 0.583841999999998
# Predictive log-likelihood for test at iteration 7000 is -0.6912067110595717
# 570.8211669921875
# learning rate:0.003961140017865888
# Train accuracy for iteration 8000 is 0.9167557339449555
# Predictive log-likelihood for trainat iteration 8000 is -0.28163663879884454
# Test accuracy is 0.9031000000000015
# Predictive log-likelihood for test at iteration 8000 is -0.3031675913314818
# 317.3065185546875
# learning rate:0.003574928866123963
# Train accuracy for iteration 9000 is 0.9729701834862401
# Predictive log-likelihood for trainat iteration 9000 is -0.11844168218232079
# Test accuracy is 0.9709560000000036
# Predictive log-likelihood for test at iteration 9000 is -0.11842950721168512
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------

# %%
models = []
for lr in [1e-3, 0.5e-3, 1e-4, 1e-5]:
    for l in [10,20,50]:
        
        print('---------------------------------------------------------------------')
        print('---------------------------------------------------------------------')
        print(colored("\n\n Start training for lr = {} and hidden_layer size = {}\n\n".format(lr, l), 'green'))
        print('---------------------------------------------------------------------')
        print('---------------------------------------------------------------------')
        model = BNN(train, label, [5, 10, 10, 2], act = nn.Tanh(), n_epochs = 10000)
        model.train(lr = 9e-3, decay = .95)
        models.append(model)
        print('---------------------------------------------------------------------')
        print('---------------------------------------------------------------------')
# Out:
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
#
#
#  Start training for lr = 0.001 and hidden_layer size = 10
#
#
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# 1063.8746337890625
# learning rate:0.009
# Train accuracy for iteration 0 is 0.4937362385321104
# Predictive log-likelihood for trainat iteration 0 is -1.5875758364266226
# Test accuracy is 0.496964
# Predictive log-likelihood for test at iteration 0 is -1.5402280909729005
# 296.7937927246094
# learning rate:0.008122499999999998
# Train accuracy for iteration 1000 is 0.9588509174311933
# Predictive log-likelihood for trainat iteration 1000 is -0.13859569748388514
# Test accuracy is 0.951402000000003
# Predictive log-likelihood for test at iteration 1000 is -0.1568568328104022
# 331.81573486328125
# learning rate:0.0073305562499999975
# Train accuracy for iteration 2000 is 0.9806020642201856
# Predictive log-likelihood for trainat iteration 2000 is -0.06757372857397845
# Test accuracy is 0.9783140000000027
# Predictive log-likelihood for test at iteration 2000 is -0.07561462121582027
# 196.03697204589844
# learning rate:0.006615827015624996
# Train accuracy for iteration 3000 is 0.986193807339451
# Predictive log-likelihood for trainat iteration 3000 is -0.04727692015646796
# Test accuracy is 0.9838500000000031
# Predictive log-likelihood for test at iteration 3000 is -0.05411416534852982
# 182.3834228515625
# learning rate:0.005970783881601559
# Train accuracy for iteration 4000 is 0.989342889908257
# Predictive log-likelihood for trainat iteration 4000 is -0.03519730800704674
# Test accuracy is 0.9856940000000025
# Predictive log-likelihood for test at iteration 4000 is -0.04580771751093865
# 270.4801025390625
# learning rate:0.005388632453145407
# Train accuracy for iteration 5000 is 0.9932110091743124
# Predictive log-likelihood for trainat iteration 5000 is -0.022941711320746874
# Test accuracy is 0.9910940000000017
# Predictive log-likelihood for test at iteration 5000 is -0.02752908905521779
# 174.7879638671875
# learning rate:0.004863240788963729
# Train accuracy for iteration 6000 is 0.9955516055045893
# Predictive log-likelihood for trainat iteration 6000 is -0.01665368706119298
# Test accuracy is 0.9941900000000045
# Predictive log-likelihood for test at iteration 6000 is -0.020321365069637543
# 170.88555908203125
# learning rate:0.004389074812039765
# Train accuracy for iteration 7000 is 0.9951284403669747
# Predictive log-likelihood for trainat iteration 7000 is -0.016112465933008017
# Test accuracy is 0.9949820000000029
# Predictive log-likelihood for test at iteration 7000 is -0.01892591989012806
# 174.70594787597656
# learning rate:0.003961140017865888
# Train accuracy for iteration 8000 is 0.9964782110091767
# Predictive log-likelihood for trainat iteration 8000 is -0.013105368088567701
# Test accuracy is 0.9944900000000029
# Predictive log-likelihood for test at iteration 8000 is -0.019119298745211184
# 170.31349182128906
# learning rate:0.003574928866123963
# Train accuracy for iteration 9000 is 0.9970745412844056
# Predictive log-likelihood for trainat iteration 9000 is -0.01200165325658687
# Test accuracy is 0.9959220000000034
# Predictive log-likelihood for test at iteration 9000 is -0.015496570589937251
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
#
#
#  Start training for lr = 0.001 and hidden_layer size = 20
#
#
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# 1528.5517578125
# learning rate:0.009
# Train accuracy for iteration 0 is 0.4973073394495407
# Predictive log-likelihood for trainat iteration 0 is -1.517008850972587
# Test accuracy is 0.5046219999999999
# Predictive log-likelihood for test at iteration 0 is -1.4938470543060298
# 285.546875
# learning rate:0.008122499999999998
# Train accuracy for iteration 1000 is 0.9620768348623854
# Predictive log-likelihood for trainat iteration 1000 is -0.1294655922924705
# Test accuracy is 0.9588780000000016
# Predictive log-likelihood for test at iteration 1000 is -0.1404421956758499
# 211.58544921875
# learning rate:0.0073305562499999975
# Train accuracy for iteration 2000 is 0.9856399082568831
# Predictive log-likelihood for trainat iteration 2000 is -0.0492066733555509
# Test accuracy is 0.9856060000000045
# Predictive log-likelihood for test at iteration 2000 is -0.049864414746284426
# 190.6774139404297
# learning rate:0.006615827015624996
# Train accuracy for iteration 3000 is 0.9937660550458726
# Predictive log-likelihood for trainat iteration 3000 is -0.021611756396642225
# Test accuracy is 0.9929860000000016
# Predictive log-likelihood for test at iteration 3000 is -0.024534356473505468
# 179.01039123535156
# learning rate:0.005970783881601559
# Train accuracy for iteration 4000 is 0.995496559633029
# Predictive log-likelihood for trainat iteration 4000 is -0.017022007314573706
# Test accuracy is 0.9952860000000026
# Predictive log-likelihood for test at iteration 4000 is -0.017999132382810108
# 167.5993194580078
# learning rate:0.005388632453145407
# Train accuracy for iteration 5000 is 0.9972075688073412
# Predictive log-likelihood for trainat iteration 5000 is -0.011399005283481976
# Test accuracy is 0.9965000000000034
# Predictive log-likelihood for test at iteration 5000 is -0.014108680433884257
# 164.71376037597656
# learning rate:0.004863240788963729
# Train accuracy for iteration 6000 is 0.9980493119266071
# Predictive log-likelihood for trainat iteration 6000 is -0.009918031584932863
# Test accuracy is 0.9973620000000044
# Predictive log-likelihood for test at iteration 6000 is -0.012181164832014611
# 164.9048309326172
# learning rate:0.004389074812039765
# Train accuracy for iteration 7000 is 0.9982327981651383
# Predictive log-likelihood for trainat iteration 7000 is -0.008566221962161705
# Test accuracy is 0.9977800000000032
# Predictive log-likelihood for test at iteration 7000 is -0.010143489294696599
# 155.56576538085938
# learning rate:0.003961140017865888
# Train accuracy for iteration 8000 is 0.9982603211009189
# Predictive log-likelihood for trainat iteration 8000 is -0.008920178794047846
# Test accuracy is 0.9972700000000043
# Predictive log-likelihood for test at iteration 8000 is -0.012219316356897342
# 154.91116333007812
# learning rate:0.003574928866123963
# Train accuracy for iteration 9000 is 0.9982213302752313
# Predictive log-likelihood for trainat iteration 9000 is -0.009905459468821131
# Test accuracy is 0.9978160000000046
# Predictive log-likelihood for test at iteration 9000 is -0.010709927522756152
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
#
#
#  Start training for lr = 0.001 and hidden_layer size = 50
#
#
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# 880.6134033203125
# learning rate:0.009
# Train accuracy for iteration 0 is 0.5016892201834862
# Predictive log-likelihood for trainat iteration 0 is -1.453958883390514
# Test accuracy is 0.5028420000000003
# Predictive log-likelihood for test at iteration 0 is -1.4826545251007084
# 281.53497314453125
# learning rate:0.008122499999999998
# Train accuracy for iteration 1000 is 0.9514610091743113
# Predictive log-likelihood for trainat iteration 1000 is -0.15893620769255745
# Test accuracy is 0.9481620000000023
# Predictive log-likelihood for test at iteration 1000 is -0.1658691938152312
# 249.62217712402344
# learning rate:0.0073305562499999975
# Train accuracy for iteration 2000 is 0.9859839449541306
# Predictive log-likelihood for trainat iteration 2000 is -0.06134544872143947
# Test accuracy is 0.9844560000000014
# Predictive log-likelihood for test at iteration 2000 is -0.06764487458896637
# 211.05545043945312
# learning rate:0.006615827015624996
# Train accuracy for iteration 3000 is 0.9887201834862427
# Predictive log-likelihood for trainat iteration 3000 is -0.053143383779657
# Test accuracy is 0.985676000000001
# Predictive log-likelihood for test at iteration 3000 is -0.06393336859035491
# 205.27781677246094
# learning rate:0.005970783881601559
# Train accuracy for iteration 4000 is 0.9898543577981661
# Predictive log-likelihood for trainat iteration 4000 is -0.051426686646741354
# Test accuracy is 0.9875899999999983
# Predictive log-likelihood for test at iteration 4000 is -0.059422254777908454
# 186.91551208496094
# learning rate:0.005388632453145407
# Train accuracy for iteration 5000 is 0.9906846330275216
# Predictive log-likelihood for trainat iteration 5000 is -0.049869676139376595
# Test accuracy is 0.989027999999997
# Predictive log-likelihood for test at iteration 5000 is -0.056002430138587925
# 207.40786743164062
# learning rate:0.004863240788963729
# Train accuracy for iteration 6000 is 0.9907213302752274
# Predictive log-likelihood for trainat iteration 6000 is -0.051201848754095336
# Test accuracy is 0.9892339999999968
# Predictive log-likelihood for test at iteration 6000 is -0.05701860316848759
# 207.220703125
# learning rate:0.004389074812039765
# Train accuracy for iteration 7000 is 0.9902649082568792
# Predictive log-likelihood for trainat iteration 7000 is -0.05187285984874868
# Test accuracy is 0.9877659999999996
# Predictive log-likelihood for test at iteration 7000 is -0.0618276179218293
# 185.35287475585938
# learning rate:0.003961140017865888
# Train accuracy for iteration 8000 is 0.9913933486238509
# Predictive log-likelihood for trainat iteration 8000 is -0.04893717992852586
# Test accuracy is 0.9887859999999961
# Predictive log-likelihood for test at iteration 8000 is -0.059109493144988944
# 202.24317932128906
# learning rate:0.003574928866123963
# Train accuracy for iteration 9000 is 0.9914495412844004
# Predictive log-likelihood for trainat iteration 9000 is -0.049345629799256684
# Test accuracy is 0.9896059999999949
# Predictive log-likelihood for test at iteration 9000 is -0.05761092153549191
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
#
#
#  Start training for lr = 0.0005 and hidden_layer size = 10
#
#
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# 2999.07861328125
# learning rate:0.009
# Train accuracy for iteration 0 is 0.49465596330275197
# Predictive log-likelihood for trainat iteration 0 is -1.5601992689710154
# Test accuracy is 0.4973659999999993
# Predictive log-likelihood for test at iteration 0 is -1.5473182494812028
# 414.2397766113281
# learning rate:0.008122499999999998
# Train accuracy for iteration 1000 is 0.952955275229356
# Predictive log-likelihood for trainat iteration 1000 is -0.15286099408525927
# Test accuracy is 0.9497180000000015
# Predictive log-likelihood for test at iteration 1000 is -0.16218021871376054
# 222.81517028808594
# learning rate:0.0073305562499999975
# Train accuracy for iteration 2000 is 0.9816639908256898
# Predictive log-likelihood for trainat iteration 2000 is -0.06696679008608569
# Test accuracy is 0.9798100000000037
# Predictive log-likelihood for test at iteration 2000 is -0.07279581702184683
# 232.56564331054688
# learning rate:0.006615827015624996
# Train accuracy for iteration 3000 is 0.9909220183486253
# Predictive log-likelihood for trainat iteration 3000 is -0.03170702650363837
# Test accuracy is 0.9881100000000012
# Predictive log-likelihood for test at iteration 3000 is -0.04072432884216314
# 187.1465606689453
# learning rate:0.005970783881601559
# Train accuracy for iteration 4000 is 0.9954116972477075
# Predictive log-likelihood for trainat iteration 4000 is -0.0185878667487259
# Test accuracy is 0.9947400000000015
# Predictive log-likelihood for test at iteration 4000 is -0.02029141020199654
# 173.5216522216797
# learning rate:0.005388632453145407
# Train accuracy for iteration 5000 is 0.9959449541284423
# Predictive log-likelihood for trainat iteration 5000 is -0.01825334518609584
# Test accuracy is 0.9957080000000031
# Predictive log-likelihood for test at iteration 5000 is -0.018767989800043426
# 168.94471740722656
# learning rate:0.004863240788963729
# Train accuracy for iteration 6000 is 0.998055045871561
# Predictive log-likelihood for trainat iteration 6000 is -0.012012214796839796
# Test accuracy is 0.9970660000000029
# Predictive log-likelihood for test at iteration 6000 is -0.014559447125062342
# 159.37893676757812
# learning rate:0.004389074812039765
# Train accuracy for iteration 7000 is 0.9982522935779834
# Predictive log-likelihood for trainat iteration 7000 is -0.009962594075282213
# Test accuracy is 0.9975740000000038
# Predictive log-likelihood for test at iteration 7000 is -0.012606282642558201
# 171.58853149414062
# learning rate:0.003961140017865888
# Train accuracy for iteration 8000 is 0.9980665137614696
# Predictive log-likelihood for trainat iteration 8000 is -0.010713812919521533
# Test accuracy is 0.997374000000003
# Predictive log-likelihood for test at iteration 8000 is -0.012235210166878997
# 151.17044067382812
# learning rate:0.003574928866123963
# Train accuracy for iteration 9000 is 0.9986123853211029
# Predictive log-likelihood for trainat iteration 9000 is -0.009123914394852354
# Test accuracy is 0.9974300000000035
# Predictive log-likelihood for test at iteration 9000 is -0.011029989235386227
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
#
#
#  Start training for lr = 0.0005 and hidden_layer size = 20
#
#
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# 3116.956787109375
# learning rate:0.009
# Train accuracy for iteration 0 is 0.4987385321100917
# Predictive log-likelihood for trainat iteration 0 is -1.5303197421852595
# Test accuracy is 0.4987480000000005
# Predictive log-likelihood for test at iteration 0 is -1.501584742172243
# 323.627197265625
# learning rate:0.008122499999999998
# Train accuracy for iteration 1000 is 0.9457305045871561
# Predictive log-likelihood for trainat iteration 1000 is -0.17587929174221972
# Test accuracy is 0.9430300000000018
# Predictive log-likelihood for test at iteration 1000 is -0.181387038057327
# 220.74270629882812
# learning rate:0.0073305562499999975
# Train accuracy for iteration 2000 is 0.9843509174311944
# Predictive log-likelihood for trainat iteration 2000 is -0.058540596240704255
# Test accuracy is 0.9830740000000048
# Predictive log-likelihood for test at iteration 2000 is -0.06466786275434502
# 183.5818634033203
# learning rate:0.006615827015624996
# Train accuracy for iteration 3000 is 0.9899610091743123
# Predictive log-likelihood for trainat iteration 3000 is -0.03540972317946617
# Test accuracy is 0.9884360000000016
# Predictive log-likelihood for test at iteration 3000 is -0.0397167280385494
# 174.6353759765625
# learning rate:0.005970783881601559
# Train accuracy for iteration 4000 is 0.9943016055045883
# Predictive log-likelihood for trainat iteration 4000 is -0.01987275000641107
# Test accuracy is 0.9927420000000047
# Predictive log-likelihood for test at iteration 4000 is -0.024715178189754484
# 174.96710205078125
# learning rate:0.005388632453145407
# Train accuracy for iteration 5000 is 0.995197247706425
# Predictive log-likelihood for trainat iteration 5000 is -0.016107171795527463
# Test accuracy is 0.9940160000000046
# Predictive log-likelihood for test at iteration 5000 is -0.021098654496848595
# 170.07110595703125
# learning rate:0.004863240788963729
# Train accuracy for iteration 6000 is 0.9959266055045887
# Predictive log-likelihood for trainat iteration 6000 is -0.015418146204348615
# Test accuracy is 0.9949820000000038
# Predictive log-likelihood for test at iteration 6000 is -0.019170356582105138
# 160.27735900878906
# learning rate:0.004389074812039765
# Train accuracy for iteration 7000 is 0.9957912844036725
# Predictive log-likelihood for trainat iteration 7000 is -0.01679619736231674
# Test accuracy is 0.9943040000000047
# Predictive log-likelihood for test at iteration 7000 is -0.023028237353414287
# 158.38685607910156
# learning rate:0.003961140017865888
# Train accuracy for iteration 8000 is 0.9968497706422045
# Predictive log-likelihood for trainat iteration 8000 is -0.011041112859712047
# Test accuracy is 0.9949460000000057
# Predictive log-likelihood for test at iteration 8000 is -0.02016196098480375
# 159.87567138671875
# learning rate:0.003574928866123963
# Train accuracy for iteration 9000 is 0.9969380733944985
# Predictive log-likelihood for trainat iteration 9000 is -0.012827560425377148
# Test accuracy is 0.9947300000000069
# Predictive log-likelihood for test at iteration 9000 is -0.021457698830332616
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
#
#
#  Start training for lr = 0.0005 and hidden_layer size = 50
#
#
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# 3199.396484375
# learning rate:0.009
# Train accuracy for iteration 0 is 0.4940011467889912
# Predictive log-likelihood for trainat iteration 0 is -1.523125329113882
# Test accuracy is 0.49857999999999997
# Predictive log-likelihood for test at iteration 0 is -1.489347054138185
# 282.3266296386719
# learning rate:0.008122499999999998
# Train accuracy for iteration 1000 is 0.9619495412844036
# Predictive log-likelihood for trainat iteration 1000 is -0.1366148797262701
# Test accuracy is 0.956986000000004
# Predictive log-likelihood for test at iteration 1000 is -0.14612468658828745
# 270.27587890625
# learning rate:0.0073305562499999975
# Train accuracy for iteration 2000 is 0.9842522935779843
# Predictive log-likelihood for trainat iteration 2000 is -0.0678203089674678
# Test accuracy is 0.9834080000000062
# Predictive log-likelihood for test at iteration 2000 is -0.06926189609718325
# 197.469482421875
# learning rate:0.006615827015624996
# Train accuracy for iteration 3000 is 0.9866261467889929
# Predictive log-likelihood for trainat iteration 3000 is -0.05293128073270167
# Test accuracy is 0.985344000000003
# Predictive log-likelihood for test at iteration 3000 is -0.05608836964511878
# 187.6554718017578
# learning rate:0.005970783881601559
# Train accuracy for iteration 4000 is 0.9900883027522933
# Predictive log-likelihood for trainat iteration 4000 is -0.03608232201184694
# Test accuracy is 0.9877280000000027
# Predictive log-likelihood for test at iteration 4000 is -0.04653561524176588
# 175.82699584960938
# learning rate:0.005388632453145407
# Train accuracy for iteration 5000 is 0.99485779816514
# Predictive log-likelihood for trainat iteration 5000 is -0.021137531048079958
# Test accuracy is 0.994582000000003
# Predictive log-likelihood for test at iteration 5000 is -0.022022959291413412
# 163.8417510986328
# learning rate:0.004863240788963729
# Train accuracy for iteration 6000 is 0.997291284403673
# Predictive log-likelihood for trainat iteration 6000 is -0.014131909850745573
# Test accuracy is 0.997204000000003
# Predictive log-likelihood for test at iteration 6000 is -0.014730245929300785
# 157.7447509765625
# learning rate:0.004389074812039765
# Train accuracy for iteration 7000 is 0.9973176605504611
# Predictive log-likelihood for trainat iteration 7000 is -0.012594981991369793
# Test accuracy is 0.9972120000000025
# Predictive log-likelihood for test at iteration 7000 is -0.014254859299063689
# 152.31015014648438
# learning rate:0.003961140017865888
# Train accuracy for iteration 8000 is 0.9975298165137646
# Predictive log-likelihood for trainat iteration 8000 is -0.012561154769742103
# Test accuracy is 0.9971820000000036
# Predictive log-likelihood for test at iteration 8000 is -0.014470351167351004
# 152.5582733154297
# learning rate:0.003574928866123963
# Train accuracy for iteration 9000 is 0.9974059633027564
# Predictive log-likelihood for trainat iteration 9000 is -0.012913587306609058
# Test accuracy is 0.9955640000000068
# Predictive log-likelihood for test at iteration 9000 is -0.02158725273400543
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
#
#
#  Start training for lr = 0.0001 and hidden_layer size = 10
#
#
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# 1346.3369140625
# learning rate:0.009
# Train accuracy for iteration 0 is 0.5014449541284408
# Predictive log-likelihood for trainat iteration 0 is -1.5339336654243125
# Test accuracy is 0.4948619999999996
# Predictive log-likelihood for test at iteration 0 is -1.5376311905517552
# 242.70350646972656
# learning rate:0.008122499999999998
# Train accuracy for iteration 1000 is 0.9066800458715598
# Predictive log-likelihood for trainat iteration 1000 is -0.2545612493130047
# Test accuracy is 0.9041980000000017
# Predictive log-likelihood for test at iteration 1000 is -0.26643529020690904
# 217.30181884765625
# learning rate:0.0073305562499999975
# Train accuracy for iteration 2000 is 0.983307339449544
# Predictive log-likelihood for trainat iteration 2000 is -0.06977583012230902
